# %% [markdown]
# Question 1 Topic:** List**
#
# *   List item
# *   List item

# %%
import random
numbers=[random.randint(1,100) for _ in range(5)]
print(numbers)
# Out:
# [6, 73, 88, 89, 1]

# %% [markdown]
#   Question 2

# %%
numbers=[6,73,88,89,1]
numbers.append(60)
numbers.append(70)
numbers.append(80)
print(numbers)
# Out:
# [6, 73, 88, 89, 1, 60, 70, 80]

# %% [markdown]
# Question 3

# %%
numbers=[6,73,88,89,1]
for numbers in numbers:
  print(numbers)
# Out:
# 6
# 73
# 88
# 89
# 1

# %% [markdown]
# Topic: **Dictionary**
# Question 1

# %%
person={"name":"John","age": 25, "address":"Newyork"}
print(person)
# Out:
# {'name': 'John', 'age': 25, 'address': 'Newyork'}

# %% [markdown]
# Question 2

# %%
person={"name":"John","age":25,"address":"Newyork"}
person["phone"]="8289860869"
print(person)
# Out:
# {'name': 'John', 'age': 25, 'address': 'Newyork', 'phone': '8289860869'}

# %% [markdown]
# Topic: **Set**
# Question 1

# %%
numbers= {1,2,3,4,5}
print (numbers)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Question 2

# %%
numbers={1,2,3,4,5,}
numbers.add(6)
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Question 3

# %%
numbers={1,2,3,4,5}
numbers.remove(3)
print(numbers)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# Topic: **Tuple**
# Question 1

# %%
numbers=(1,2,3,4)
print(numbers)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# Question 2

# %%
numbers=(1,2,3,4)
print(len(numbers))
# Out:
# 4
